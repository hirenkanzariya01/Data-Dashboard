# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df =sns.load_dataset('tips')

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df['tip'].dtype
# Out:
# dtype('float64')

# %%
d = {
        "Name": ["Vivo", "Oppo", "Mi", "I-phone", "One Plus", "Redme"],
        "Seals": [150, 200, 100, 360, 260, np.nan],
        "Price": [35000, np.nan, 15000, 68000, 45000, 21000],
        "unit": [20, 35, 55, 45, 12, 32],
    }
data = pd.DataFrame(d)

# %%
data.columns[data.isnull().any()]
# Out:
# Index(['Seals', 'Price'], dtype='object')

# %%
data
# Out:
#        Name  Seals    Price  unit
# 0      Vivo  150.0  35000.0    20
# 1      Oppo  200.0      NaN    35
# 2        Mi  100.0  15000.0    55
# 3   I-phone  360.0  68000.0    45
# 4  One Plus  260.0  45000.0    12
# 5     Redme    NaN  21000.0    32

# %%
data['Price'].fillna(data['Price'].mode(), inplace=True)

# %%
data
# Out:
#        Name  Seals    Price  unit
# 0      Vivo  150.0  35000.0    20
# 1      Oppo  200.0      0.0    35
# 2        Mi  100.0  15000.0    55
# 3   I-phone  360.0  68000.0    45
# 4  One Plus  260.0  45000.0    12
# 5     Redme    NaN  21000.0    32
